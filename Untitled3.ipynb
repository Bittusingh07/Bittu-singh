# %%
type("2")
# Out:
# str

# %%
print("bittu")
# Out:
# bittu

# %%
max("bittu")
# Out:
# 'u'

# %%
min("bittu")
# Out:
# 'b'

# %%
str+str2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 str+str2
#
# NameError: name 'str2' is not defined
