# %%
from google import genai

# %%
import random
random.randint(1,10)
# Out:
# 6

# %%
from random import randint
randint(1,10)
# Out:
# 3

# %%
client = genai.client()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 client = genai.client()
#
# TypeError: 'module' object is not callable

# %%
import google.generativeai as genai

# %%
genai.configure(api_key="AIzaSyBvu67N0bEvsNEkH-G2AVQdYYFuD-J3Oy4")

# %%
dir(genai)
# Out:
# ['ChatSession',
#  'GenerationConfig',
#  'GenerativeModel',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'annotations',
#  'caching',
#  'configure',
#  'create_tuned_model',
#  'delete_file',
#  'delete_tuned_model',
#  'embed_content',
#  'embed_content_async',
#  'get_base_model',
#  'get_file',
#  'get_model',
#  'get_operation',
#  'get_tuned_model',
#  'list_files',
#  'list_models',
#  'list_operations',
#  'list_tuned_models',
#  'protos',
#  'responder',
#  'string_utils',
#  'types',
#  'update_tuned_model',
#  'upload_file',
#  'utils']

# %%
genai.list_models()
# Out:
# <generator object list_models at 0x000001C9DC6A97B0>

# %%
genai.GenerativeModel()
# Out:
# genai.GenerativeModel(
#     model_name='models/gemini-1.5-flash-002',
#     generation_config={},
#     safety_settings={},
#     tools=None,
#     system_instruction=None,
#     cached_content=None
# )

# %%
list(genai.list_models())
# Out:
# [Model(name='models/embedding-gecko-001',
#        base_model_id='',
#        version='001',
#        display_name='Embedding Gecko',
#        description='Obtain a distributed representation of a text.',
#        input_token_limit=1024,
#        output_token_limit=1,
#        supported_generation_methods=['embedText', 'countTextTokens'],
#        temperature=None,
#        max_temperature=None,
#        top_p=None,
#        top_k=None),
#  Model(name='models/gemini-1.5-pro-latest',
#        base_model_id='',
#        version='001',
#        display_name='Gemini 1.5 Pro Latest',
#        description=('Alias that points to the most recent production (non-experimental) release '
#                     'of Gemini 1.5 Pro, our mid-size multimodal model that supports up to 2 '
#                     'million tokens.'),
#        input_token_limit=2000000,
#        output_token_limit=8192,
#        supported_generation_methods=['generateContent', 'countTokens'],
#        temperature=1.0,
# ...

# %%
model_name='models/gemini-2.5-flash'

# %%
dir(genai)
# Out:
# ['ChatSession',
#  'GenerationConfig',
#  'GenerativeModel',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'annotations',
#  'caching',
#  'configure',
#  'create_tuned_model',
#  'delete_file',
#  'delete_tuned_model',
#  'embed_content',
#  'embed_content_async',
#  'get_base_model',
#  'get_file',
#  'get_model',
#  'get_operation',
#  'get_tuned_model',
#  'list_files',
#  'list_models',
#  'list_operations',
#  'list_tuned_models',
#  'protos',
#  'responder',
#  'string_utils',
#  'types',
#  'update_tuned_model',
#  'upload_file',
#  'utils']

# %%
genai.GenerativeModel(model_name='models/gemini-2.5-flash')
# Out:
# genai.GenerativeModel(
#     model_name='models/gemini-2.5-flash',
#     generation_config={},
#     safety_settings={},
#     tools=None,
#     system_instruction=None,
#     cached_content=None
# )

# %%
import google.generativeai as genai
dir(genai)
#configure
genai.configure(api_key='AIzaSyBvu67N0bEvsNEkH-G2AVQdYYFuD-J3Oy4')
#list models
list(genai.list_models())
model_name='models/gemini-2.5-flash'
#generativeai model
model=genai.GenerativeModel(model_name='models/gemini-2.5-flash')
response=model.generate_content("list of top 5 indian crickters")
print(response.text)
# Out:
# Listing the "top 5" Indian cricketers is always a fun and challenging debate, as so many legends have graced the game! It depends heavily on criteria like impact, longevity, statistics, leadership, and across different formats/eras.
#
# However, based on overall influence, records, and consistent performance across their careers, here's a widely accepted list of top 5, in no particular order, with a brief reason:
#
# 1.  **Sachin Tendulkar:**
#     *   **Why:** Widely regarded as the "God of Cricket," he holds numerous batting records, including the most runs in both Tests and ODIs, and an unprecedented 100 international centuries. His career spanned over two decades, and he carried the hopes of a nation for much of that time.
#
# 2.  **Virat Kohli:**
# ...
